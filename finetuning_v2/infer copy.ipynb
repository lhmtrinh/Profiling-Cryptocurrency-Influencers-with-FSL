# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from print_result import print_result
import pandas as pd

# %%
MODELS = [
    {
        'model_name': 'google/electra-large-discriminator',
        'model_path': '/home/ubuntu/Profiling-Cryptocurrency-Influencers-with-FSL/finetuning_v2/google/electra-large-discriminator'
    }
]

val_df = pd.read_csv('../data/finetune_train_val_test/validate.csv')

# %%
for d in MODELS:
    model_path = d['model_path']
    model_name = d['model_name']
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_path)

    print_result(val_df, model, model_name, tokenizer)
